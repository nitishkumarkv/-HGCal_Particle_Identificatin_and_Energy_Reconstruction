# %%
#import the stuff
import pandas as pd #dataframes etc
import matplotlib.pyplot as plt #plotting
import pickle
import numpy as np
import os, sys
import seaborn as sns
import pickle
import numpy as np
import ROOT
# %jsroot on


folder = "0to5M_fixwt_trimAhcal_relwtUpd_semiparam_mina_1_ratio_maxlr6e-4_lrSchCyclic_2agg_lay_gauss_edge_nsm"


pred_v2 ="/eos/user/n/nkasarag/gnn_results/%s/pred_sim.pickle"%folder
with open(pred_v2, "rb") as f:
    preds_trueEn = np.array(pickle.load(f))
    pred = preds_trueEn
#preds_trueEn = np.exp(-preds_trueEn)

#predPickle = open(pred_v2, "rb")
#print(predPickle)
#preds_trueEn = np.asarray(pickle.load(predPickle))
#preds_trueEn = np.load(pred_v2)

rawE = np.load("/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay/rawE.npy")
#rawE = np.load("/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay_msi_10M/rawE.npy")

preds_trueEn = (preds_trueEn<3)*preds_trueEn + (preds_trueEn>3)*3
pred = (pred<3)*pred + (pred>3)*3

preds_trueEn = preds_trueEn*rawE

#print(preds[0])
import awkward

trueEn= "/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay/trueE.npy"
#trueEn= "/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay_msi_10M/trueE.npy"

trueEn_pkl = np.load(trueEn)
# Out:
# Welcome to JupyROOT 6.22/06

# %%
pred
# Out:
# array([0.7446062 , 0.6474843 , 0.74733222, ..., 0.93538761, 0.81496358,
#        1.04849136])

# %%
c=ROOT.TCanvas()

#c.SetGrid()
H_pion = ROOT.TH1F("H_pion",";Ratio of E_{true} to E_{raw};Normalized to unit area", 200,-0.1,20)

#rawE = np.load("/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay/rawE.npy")
x = trueEn_pkl/rawE

for i in range(x.size):
        H_pion.Fill(x[i])
        

    
#H_pion.Draw("COlZ")

H_pion.GetXaxis().SetTitleSize(0.045)
H_pion.GetXaxis().SetTitleOffset(1)

H_pion.GetYaxis().SetTitleSize(0.045)

H_pion.DrawNormalized()

ROOT.gStyle.SetOptStat(1)

ROOT.gPad.SetLogy()
#c.SetGrid()
c.Draw()

c.SaveAs("/eos/user/n/nkasarag/ImagesForThesis/HGCAL_TB_GNN/trueE_by_rawE.pdf")
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: H_pion (Potential memory leak).
# Info in <TCanvas::Print>: pdf file /eos/user/n/nkasarag/ImagesForThesis/HGCAL_TB_GNN/trueE_by_rawE.pdf has been created
# <div id="root_plot_1680089456717"
#      style="width: 696px; height: 472px">
# </div>
# <script>
# if (typeof require !== 'undefined') {
#
#     // All requirements met (we are in jupyter notebooks or we loaded requirejs before).
#     display_root_plot_1680089456717();
#
# } else {
#
#     // We are in jupyterlab, we need to insert requirejs and configure it.
#     // Jupyterlab might be installed in a different base_url so we need to know it.
#     try {
#         var base_url = JSON.parse(document.getElementById('jupyter-config-data').innerHTML).baseUrl;
#     } catch(_) {
#         var base_url = '/';
#     }
#
#     // Try loading a local version of requirejs and fallback to cdn if not possible.
# ...

# %%
c=ROOT.TCanvas()

#c.SetGrid()
H_pion = ROOT.TH1F("H_pion",";E_{true} [GeV];Normalized to unit area", 200,-0.1,420)

#rawE = np.load("/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay/rawE.npy")
x = trueEn_pkl

for i in range(x.size):
        H_pion.Fill(x[i])
        
H_pion.GetXaxis().SetTitleSize(0.045)
H_pion.GetXaxis().SetTitleOffset(1)

H_pion.GetYaxis().SetTitleSize(0.045)
H_pion.GetYaxis().SetTitleOffset(1.1)
    
#H_pion.Draw("COlZ")



H_pion.DrawNormalized()

ROOT.gStyle.SetOptStat(1)

#c.SetGrid()
c.Draw()
c.SaveAs("/eos/user/n/nkasarag/ImagesForThesis/HGCAL_TB_GNN/trueE.pdf")
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: H_pion (Potential memory leak).
# Info in <TCanvas::Print>: pdf file /eos/user/n/nkasarag/ImagesForThesis/HGCAL_TB_GNN/trueE.pdf has been created
# <div id="root_plot_1680089461760"
#      style="width: 696px; height: 472px">
# </div>
# <script>
# if (typeof require !== 'undefined') {
#
#     // All requirements met (we are in jupyter notebooks or we loaded requirejs before).
#     display_root_plot_1680089461760();
#
# } else {
#
#     // We are in jupyterlab, we need to insert requirejs and configure it.
#     // Jupyterlab might be installed in a different base_url so we need to know it.
#     try {
#         var base_url = JSON.parse(document.getElementById('jupyter-config-data').innerHTML).baseUrl;
#     } catch(_) {
#         var base_url = '/';
#     }
#
#     // Try loading a local version of requirejs and fallback to cdn if not possible.
# ...

# %%
with open("/eos/user/n/nkasarag/SWAN_projects/HGCal_Particle_Identificatin_and_Energy_Reconstruction/pion_energy_reconstruction_aug_2022/features/all_trainidx_gauss_egde.pickle", "rb") as f:
    gauss_train_idx = pickle.load(f)
    
with open("/eos/user/n/nkasarag/SWAN_projects/HGCal_Particle_Identificatin_and_Energy_Reconstruction/pion_energy_reconstruction_aug_2022/features/flat_60to300_trainidx.pickle", "rb") as f:
    flat_60to300_train_idx = pickle.load(f)

# %%
folder = "0to5M_fixwt_trimAhcal_relwtUpd_semiparam_mina_1_ratio_maxlr6e-4_lrSchCyclic_2agg_lay_gauss_edge_nsm"


pred_v2 ="/eos/user/n/nkasarag/gnn_results/%s/pred_sim.pickle"%folder
with open(pred_v2, "rb") as f:
    preds_trueEn = np.array(pickle.load(f))
    pred = preds_trueEn
#preds_trueEn = np.exp(-preds_trueEn)

#predPickle = open(pred_v2, "rb")
#print(predPickle)
#preds_trueEn = np.asarray(pickle.load(predPickle))
#preds_trueEn = np.load(pred_v2)

rawE = np.load("/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay/rawE.npy")
#rawE = np.load("/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay_msi_10M/rawE.npy")

preds_trueEn = (preds_trueEn<3)*preds_trueEn + (preds_trueEn>3)*3
pred = (pred<3)*pred + (pred>3)*3

preds_trueEn = preds_trueEn*rawE

#print(preds[0])
import awkward

trueEn= "/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay/trueE.npy"
#trueEn= "/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay_msi_10M/trueE.npy"

trueEn_pkl = np.load(trueEn)


c=ROOT.TCanvas()

#c.SetGrid()
H_pion = ROOT.TH1F("H_pion","Training set energy distribution;Energy (GeV);Frequency", 200,-0.1,370)
H_pion2 = ROOT.TH1F("H_pion2","Training set energy distribution;Energy [GeV];Normalized to unit area", 200,-0.1,370)

idx = gauss_train_idx
#idx = flat_60to300_train_idx

x = trueEn_pkl[idx]
y = preds_trueEn[idx]

for i in range(x.size):
        H_pion.Fill(x[i])
        
for i in range(y.size):
        H_pion2.Fill(y[i])
    
#H_pion.Draw("COlZ")

H_pion.SetLineColor(1)
H_pion2.SetLineColor(2)


H_pion2.GetXaxis().SetTitleSize(0.045)

H_pion2.GetYaxis().SetTitleSize(0.045)
H_pion2.GetYaxis().SetTitleOffset(1.1)

H_pion2.DrawNormalized()
H_pion.DrawNormalized("same")

legend = ROOT.TLegend(0.3, 0.4, 0.65, 0.6);
legend.AddEntry("H_pion","True Energy","l");
legend.AddEntry("H_pion2","Predicted Energy","l");

legend.Draw();

ROOT.gStyle.SetOptStat(0)

#ROOT.gPad.SetLogy()
#c.SetGrid()
c.Draw()

c.SaveAs("/eos/user/n/nkasarag/ImagesForThesis/HGCAL_TB_GNN/gauss_60to300.pdf")
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: H_pion (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: H_pion2 (Potential memory leak).
# Info in <TCanvas::Print>: pdf file /eos/user/n/nkasarag/ImagesForThesis/HGCAL_TB_GNN/gauss_60to300.pdf has been created
# <div id="root_plot_1679855613676"
#      style="width: 696px; height: 472px">
# </div>
# <script>
# if (typeof require !== 'undefined') {
#
#     // All requirements met (we are in jupyter notebooks or we loaded requirejs before).
#     display_root_plot_1679855613676();
#
# } else {
#
#     // We are in jupyterlab, we need to insert requirejs and configure it.
#     // Jupyterlab might be installed in a different base_url so we need to know it.
#     try {
#         var base_url = JSON.parse(document.getElementById('jupyter-config-data').innerHTML).baseUrl;
#     } catch(_) {
#         var base_url = '/';
#     }
#
# ...

# %%
folder = "0to5M_fixwt_trimAhcal_relwtUpd_semiparam_mina_1_ratio_maxlr6e-4_lrSchCyclic_2agg_lay_flat_60to300_nsm"


pred_v2 ="/eos/user/n/nkasarag/gnn_results/%s/pred_sim.pickle"%folder
with open(pred_v2, "rb") as f:
    preds_trueEn = np.array(pickle.load(f))
    pred = preds_trueEn
#preds_trueEn = np.exp(-preds_trueEn)

#predPickle = open(pred_v2, "rb")
#print(predPickle)
#preds_trueEn = np.asarray(pickle.load(predPickle))
#preds_trueEn = np.load(pred_v2)

rawE = np.load("/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay/rawE.npy")
#rawE = np.load("/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay_msi_10M/rawE.npy")

preds_trueEn = (preds_trueEn<3)*preds_trueEn + (preds_trueEn>3)*3
pred = (pred<3)*pred + (pred>3)*3

preds_trueEn = preds_trueEn*rawE

#print(preds[0])
import awkward

trueEn= "/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay/trueE.npy"
#trueEn= "/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay_msi_10M/trueE.npy"

trueEn_pkl = np.load(trueEn)


c=ROOT.TCanvas()

#c.SetGrid()
H_pion = ROOT.TH1F("H_pion","Training set energy distribution;Energy (GeV);Frequency", 200,-0.1,370)
H_pion2 = ROOT.TH1F("H_pion2","Training set energy distribution;Energy [GeV];Normalized to unit area", 200,-0.1,370)

#idx = gauss_train_idx
idx = flat_60to300_train_idx

x = trueEn_pkl[idx]
y = preds_trueEn[idx]

for i in range(x.size):
        H_pion.Fill(x[i])
        
for i in range(y.size):
        H_pion2.Fill(y[i])
    
#H_pion.Draw("COlZ")

H_pion.SetLineColor(1)
H_pion2.SetLineColor(2)

H_pion2.GetXaxis().SetTitleSize(0.045)

H_pion2.GetYaxis().SetTitleSize(0.045)
H_pion2.GetYaxis().SetTitleOffset(1.1)


H_pion2.DrawNormalized()
H_pion.DrawNormalized("same")

legend = ROOT.TLegend(0.3, 0.4, 0.65, 0.6);
legend.AddEntry("H_pion","True Energy","l");
legend.AddEntry("H_pion2","Predicted Energy","l");

legend.Draw();

ROOT.gStyle.SetOptStat(0)

#ROOT.gPad.SetLogy()
#c.SetGrid()
c.Draw()

c.SaveAs("/eos/user/n/nkasarag/ImagesForThesis/HGCAL_TB_GNN/flat_60to300.pdf")
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: H_pion (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: H_pion2 (Potential memory leak).
# Info in <TCanvas::Print>: pdf file /eos/user/n/nkasarag/ImagesForThesis/HGCAL_TB_GNN/flat_60to300.pdf has been created
# <div id="root_plot_1679855616879"
#      style="width: 696px; height: 472px">
# </div>
# <script>
# if (typeof require !== 'undefined') {
#
#     // All requirements met (we are in jupyter notebooks or we loaded requirejs before).
#     display_root_plot_1679855616879();
#
# } else {
#
#     // We are in jupyterlab, we need to insert requirejs and configure it.
#     // Jupyterlab might be installed in a different base_url so we need to know it.
#     try {
#         var base_url = JSON.parse(document.getElementById('jupyter-config-data').innerHTML).baseUrl;
#     } catch(_) {
#         var base_url = '/';
#     }
#
# ...

# %%
folder = "0to5M_fixwt_trimAhcal_relwtUpd_semiparam_mina_1_tureE_maxlr6e-4_lrSchCyclic_2agg_lay_nsm"


pred_v2 ="/eos/user/n/nkasarag/gnn_results/%s/pred_sim.pickle"%folder
with open(pred_v2, "rb") as f:
    preds_trueEn = np.array(pickle.load(f))
    pred = preds_trueEn
#preds_trueEn = np.exp(-preds_trueEn)

#predPickle = open(pred_v2, "rb")
#print(predPickle)
#preds_trueEn = np.asarray(pickle.load(predPickle))
#preds_trueEn = np.load(pred_v2)

rawE = np.load("/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay/rawE.npy")
#rawE = np.load("/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay_msi_10M/rawE.npy")

#preds_trueEn = (preds_trueEn<3)*preds_trueEn + (preds_trueEn>3)*3
#pred = (pred<3)*pred + (pred>3)*3

#preds_trueEn = preds_trueEn*rawE

#print(preds[0])
import awkward

trueEn= "/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay/trueE.npy"
#trueEn= "/eos/user/n/nkasarag/gnn_results/0to5M_fixwt_trimAhcal_relwtUpd_semiparam_ratio_maxlr6e-4_lrSchCyclic_2agg_lay_msi_10M/trueE.npy"

trueEn_pkl = np.load(trueEn)




folder2 = "0to5M_fixwt_trimAhcal_relwtUpd_semiparam_mina_1_ratio_maxlr6e-4_lrSchCyclic_2agg_lay_nsm"


pred_v22 ="/eos/user/n/nkasarag/gnn_results/%s/pred_sim.pickle"%folder2
with open(pred_v22, "rb") as f:
    preds_trueEn2 = np.array(pickle.load(f))
    pred2 = preds_trueEn2



preds_trueEn2 = (preds_trueEn2<3)*preds_trueEn2 + (preds_trueEn2>3)*3
pred2 = (pred2<3)*pred2 + (pred2>3)*3

preds_trueEn2 = preds_trueEn2*rawE



c=ROOT.TCanvas()

#c.SetGrid()
H_pion = ROOT.TH1F("H_pion","Energy Distribution;Energy (GeV);Frequency", 200,-0.1,400)
H_pion2 = ROOT.TH1F("H_pion2","Energy Distribution;Energy [GeV];Normalized to unit area", 200,-0.1,400)
H_pion3 = ROOT.TH1F("H_pion3","Energy Distribution;Energy (GeV);Frequency", 200,-0.1,400)

x = trueEn_pkl
y = preds_trueEn
z = preds_trueEn2

for i in range(x.size):
        H_pion.Fill(x[i])
        
for i in range(y.size):
        H_pion2.Fill(y[i])
        
for i in range(z.size):
        H_pion3.Fill(z[i])
    
#H_pion.Draw("COlZ")

H_pion.SetLineColor(1)
H_pion2.SetLineColor(6)
H_pion3.SetLineColor(4)

H_pion2.GetXaxis().SetTitleSize(0.045)

H_pion2.GetYaxis().SetTitleSize(0.045)
H_pion2.GetYaxis().SetTitleOffset(1.1)


H_pion2.DrawNormalized()
H_pion.DrawNormalized("same")
H_pion3.DrawNormalized("same")

legend = ROOT.TLegend(0.25, 0.35, 0.7, 0.65);
legend.AddEntry("H_pion","True Energy","l");
legend.AddEntry("H_pion2","Predicted Energy (#color[6]{DRN-TrueE})","l");
legend.AddEntry("H_pion3","Predicted Energy (#color[4]{DRN-Ratio})","l");

legend.Draw();

ROOT.gStyle.SetOptStat(0)

#ROOT.gPad.SetLogy()
#c.SetGrid()
c.Draw()

c.SaveAs("/eos/user/n/nkasarag/ImagesForThesis/HGCAL_TB_GNN/ene_dist_3models.pdf")
# Out:
# Info in <TCanvas::Print>: pdf file /eos/user/n/nkasarag/ImagesForThesis/HGCAL_TB_GNN/ene_dist_3models.pdf has been created
# <div id="root_plot_1680084619089"
#      style="width: 696px; height: 472px">
# </div>
# <script>
# if (typeof require !== 'undefined') {
#
#     // All requirements met (we are in jupyter notebooks or we loaded requirejs before).
#     display_root_plot_1680084619089();
#
# } else {
#
#     // We are in jupyterlab, we need to insert requirejs and configure it.
#     // Jupyterlab might be installed in a different base_url so we need to know it.
#     try {
#         var base_url = JSON.parse(document.getElementById('jupyter-config-data').innerHTML).baseUrl;
#     } catch(_) {
#         var base_url = '/';
#     }
#
#     // Try loading a local version of requirejs and fallback to cdn if not possible.
#     requirejs_load(base_url + 'static/components/requirejs/require.js', requirejs_success(base_url), function(){
# ...
